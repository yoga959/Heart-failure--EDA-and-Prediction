# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/Hp/Downloads/heart_failure_clinical_records_dataset.csv')
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data.shape
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig,axes=plt.subplots(1,6 ,figsize=(20,4))
features=['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure']

for i, feature in enumerate(features):
    sns.histplot(data[feature], kde=True,ax=axes[i],color='blue')
    axes[i].set_title(f'{feature}')
    axes[i].set_xlabel('value')
    axes[i].set_ylabel('count')
plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,6,figsize=(20,4))

features=['platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time']

for i,feature in enumerate(features):
    sns.histplot(data[feature],kde=True,color='Blue'
                 ,ax=axes[i])
    axes[i].set_title(f'{feature}')
    axes[i].set_xlabel('values')
    axes[i].set_ylabel('count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### corr heat map-smoking v/s sex, age v/s target , serum_creatinine v/s target shows highest corr

# %%
R=plt.figure(figsize=(18,10))
sns.heatmap(data.corr(),annot=True,cmap='coolwarm')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(x=data['DEATH_EVENT'])
plt.show()

# %%
cr=pd.crosstab(data['anaemia'],data['DEATH_EVENT'])
b=cr.plot.bar(rot=0)
b.set_xticklabels(['No Anaemia', 'Anaemia'])
for p in b.patches:
    b.annotate(
        str(int(p.get_height())),  #  bar height in counts
        (p.get_x() + p.get_width() / 2, p.get_height()),  # Coordinates
        ha='center', va='bottom', fontsize=10, color='black'
    )
plt.ylabel("Death")
# Out:
# Text(0, 0.5, 'Death')

# %%
cr=pd.crosstab(data['diabetes'],data['DEATH_EVENT'])
b=cr.plot.bar(rot=0)
b.set_xticklabels(['No diabetes', 'diabetes'])
for p in b.patches:
    b.annotate(
        str(int(p.get_height())),  #  bar height in counts
        (p.get_x() + p.get_width() / 2, p.get_height()),  # Coordinates
        ha='center', va='bottom', fontsize=10, color='black'
    )
plt.ylabel("Death")
# Out:
# Text(0, 0.5, 'Death')

# %%
cr=pd.crosstab(data['sex'],data['DEATH_EVENT'])
b=cr.plot.bar(rot=0)
b.set_xticklabels(['women', 'man'])
for p in b.patches:
    b.annotate(
        str(int(p.get_height())),  #  bar height in counts
        (p.get_x() + p.get_width() / 2, p.get_height()),  # Coordinates
        ha='center', va='bottom', fontsize=10, color='black'
    )
plt.ylabel("Death")
# Out:
# Text(0, 0.5, 'Death')

# %%
cr=pd.crosstab(data['high_blood_pressure'],data['DEATH_EVENT'])
b=cr.plot.bar(rot=0)
b.set_xticklabels(['NO BP', 'BP'])
for p in b.patches:
    b.annotate(
        str(int(p.get_height())),  #  bar height in counts
        (p.get_x() + p.get_width() / 2, p.get_height()),  # Coordinates
        ha='center', va='bottom', fontsize=10, color='black'
    )
plt.ylabel("Death")
# Out:
# Text(0, 0.5, 'Death')

# %%
bins = [0,20,40,60,80,100]
labels = ['0-20','20-40','40-60','60-80','80-100']

data['age_bins'] = pd.cut(data['age'], bins=bins, labels=labels, right=True)
age_crosstab = pd.crosstab(data['age_bins'], data['DEATH_EVENT'])
ax = age_crosstab.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.xlabel('Creatinine Phosphokinase Bins')

plt.title('age vs Death Event')
plt.legend(title='DEATH_EVENT', loc='upper right')

# %%
bins = [0, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
labels = [f"<= {b}" for b in bins[1:]]

data['cp_bins'] = pd.cut(data['creatinine_phosphokinase'], bins=bins, labels=labels, right=True)
cp_crosstab = pd.crosstab(data['cp_bins'], data['DEATH_EVENT'])
ax = cp_crosstab.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')
plt.xlabel('Creatinine Phosphokinase Bins')
plt.ylabel('Count')
plt.title('Cross Tabulation of Creatinine Phosphokinase vs Death Event')
plt.legend(title='DEATH_EVENT', loc='upper right')

# %%
data['ejection_fraction'].unique()
bins=[0,20,40,60,80]
labels=[f"<= {b}" for b in bins[1:]]
ej_cross_bins=pd.cut(data['ejection_fraction'], bins=bins, labels=labels, right=True)
ej_cross=pd.crosstab(ej_cross_bins,data['DEATH_EVENT'])
ej_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='ejection_fraction'>

# %%
data['platelets'].max()
# Out:
# 850000.0

# %%
data['platelets'].unique()
bins=[0, 10000, 20000, 30000, 40000, 50000, 60000, 70000, 80000, 90000]
labels=[f"<= {b}" for b in bins[1:]]
pl_cross_bins=pd.cut(data['platelets'], bins=bins, labels=labels, right=True)
pl_cross=pd.crosstab(pl_cross_bins,data['DEATH_EVENT'])
pl_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='platelets'>

# %%
data['serum_creatinine'].unique()
bins=[0,2,4,6,8,10]
labels=['0-2','2-4','4-6','6-8','8-10']
sc_cross_bins=pd.cut(data['serum_creatinine'], bins=bins, labels=labels, right=True)
sc_cross=pd.crosstab(sc_cross_bins,data['DEATH_EVENT'])
sc_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='serum_creatinine'>

# %%
data['serum_creatinine'].unique()
bins=[0,0.5,1,1.5,2,2.5,3,3.5,4]
labels=['0-0.5','0.5-1','1-1.5','1.5-2','2-2.5','2.5-3','3-3.5','3.5-4']
sc_cross_bins=pd.cut(data['serum_creatinine'], bins=bins, labels=labels, right=True)
sc_cross=pd.crosstab(sc_cross_bins,data['DEATH_EVENT'])
sc_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='serum_creatinine'>

# %%
cr=pd.crosstab(data['serum_sodium'],data['DEATH_EVENT'])
cr.plot.bar(rot=0,figsize=(12, 8))
# Out:
# <Axes: xlabel='serum_sodium'>

# %%
bins=[100,110,120,130,140,150]
labels=[f"<= {b}" for b in bins[1:]]
sc_cross_bins=pd.cut(data['serum_sodium'], bins=bins, labels=labels, right=True)
sc_cross=pd.crosstab(sc_cross_bins,data['DEATH_EVENT'])
sc_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='serum_sodium'>

# %%
bins=[0,50,100,150,200]
labels=[f"<= {b}" for b in bins[1:]]
time_cross_bins=pd.cut(data['time'], bins=bins, labels=labels, right=True)
time_cross=pd.crosstab(time_cross_bins,data['DEATH_EVENT'])
time_cross.plot.bar(rot=0)


bins=[0,10,20,30,40,50]
labels=[f"<= {b}" for b in bins[1:]]
time_cross_bins=pd.cut(data['time'], bins=bins, labels=labels, right=True)
time_cross=pd.crosstab(time_cross_bins,data['DEATH_EVENT'])
time_cross.plot.bar(rot=0)
# Out:
# <Axes: xlabel='time'>

# %%
x_train=data.iloc[:,:12]
x_test=data.iloc[:,:12]

y_train=data['DEATH_EVENT']
y_test=data['DEATH_EVENT']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.20,random_state=43)

# %% [markdown]
# ##### Finding imp feature based on random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
R=RandomForestClassifier()
R.fit(x_train,y_train)
prediction=R.predict(x_test)
print("The accuracy by using original dataset:",metrics.accuracy_score(prediction,y_test))
print("Accuracy by using original dataset:",metrics.precision_score(prediction,y_test))
print("Accuracy by using original dataset:",metrics.recall_score(prediction,y_test))
# Out:
# The accuracy by using original dataset: 0.7833333333333333
# Accuracy by using original dataset: 0.5769230769230769
# Accuracy by using original dataset: 0.8823529411764706

# %%
feature_importances = R.feature_importances_
print(feature_importances)
# Out:
# [0.08685695 0.01237565 0.07613085 0.01067571 0.12959255 0.0126856
#  0.08082873 0.12008365 0.07432486 0.0100889  0.01479334 0.3715632 ]

# %%
indices = np.argsort(feature_importances)[::-1]
num_features = 10
top_indices = indices[:num_features]
top_importances = feature_importances[top_indices]



print("Top 10 feature rankings based on random forest:")
for f in range(num_features): 
    print(f"{f+1}. {x_train.columns[indices[f]]}: {feature_importances[indices[f]]}")

plt.barh(range(num_features), top_importances, align="center")
plt.yticks(range(num_features), x_train.columns[top_indices])
plt.xlabel("Feature Importance based on random forest")
plt.ylabel("Feature")
plt.show()
# Out:
# Top 10 feature rankings based on random forest:
# 1. time: 0.3715631998656931
# 2. ejection_fraction: 0.12959254953512783
# 3. serum_creatinine: 0.12008365000698165
# 4. age: 0.08685695000486311
# 5. platelets: 0.08082873432634939
# 6. creatinine_phosphokinase: 0.07613084954139555
# 7. serum_sodium: 0.07432486216515997
# 8. smoking: 0.014793337024871572
# 9. high_blood_pressure: 0.012685604582826063
# 10. anaemia: 0.012375649835455513

# %% [markdown]
# ### From spearman Rank  feature selection :serum_creatinine(0.37),age (0.21), high BP(0.079) shows highest corr

# %%
from scipy import stats
features=['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure', 'platelets',
       'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time','DEATH_EVENT'
       ]
for feature in features:
    value=stats.spearmanr(data[feature],data['DEATH_EVENT'])
    
    print(value)
# Out:
# SignificanceResult(statistic=0.2181245653314277, pvalue=0.00014364541599468753)
# SignificanceResult(statistic=0.06627009846028782, pvalue=0.25329881456436526)
# SignificanceResult(statistic=0.023615927434101253, pvalue=0.6842255375313783)
# SignificanceResult(statistic=-0.0019428833442034863, pvalue=0.9733118267847669)
# SignificanceResult(statistic=-0.2868685329791511, pvalue=4.5092853831851956e-07)
# SignificanceResult(statistic=0.07935105769128536, pvalue=0.1711494985293534)
# SignificanceResult(statistic=-0.046199760077033435, pvalue=0.42606258516427864)
# SignificanceResult(statistic=0.37063004144352746, pvalue=3.612151048582716e-11)
# SignificanceResult(statistic=-0.20983690905972469, pvalue=0.00025820209227281094)
# SignificanceResult(statistic=-0.004316376319703061, pvalue=0.9407519123206658)
# SignificanceResult(statistic=-0.012623152709359603, pvalue=0.8279207128092407)
# SignificanceResult(statistic=-0.5431786961003566, pvalue=2.3932644197218766e-24)
# ...

# %%
data.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT', 'age_bins'],
#       dtype='object')

# %%
data.drop('age_bins',axis=1,inplace=True)

# %% [markdown]
# ### spearman rank: serum_creatinine(0.37),age (0.21)

# %%
x=data
x.corr(method="spearman")
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.071924                 -0.093078
# anaemia                   0.071924  1.000000                 -0.216116
# creatinine_phosphokinase -0.093078 -0.216116                  1.000000
# diabetes                 -0.089657 -0.012729                  0.042308
# ejection_fraction         0.074047  0.020366                 -0.067839
# high_blood_pressure       0.105740  0.038182                 -0.080724
# platelets                -0.052091 -0.035608                  0.060033
# serum_creatinine          0.270561 -0.016267                 -0.049936
# serum_sodium             -0.101716  0.061405                  0.016886
# sex                       0.057791 -0.094769                  0.013298
# smoking                   0.030145 -0.107290                 -0.030351
# time                     -0.197524 -0.134652                  0.125823
# ...

# %% [markdown]
# ### Pearson method of feature selection:serum_creatinine(0.29), age(0.25)

# %%
x=data
x.corr(method="pearson")
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %% [markdown]
# #### After feature selection:
#  Removing less important features: Smoking, Anemia, Serum_sodium

# %%
X=data[['age','creatinine_phosphokinase', 'diabetes',
       'ejection_fraction', 'high_blood_pressure','platelets',
       'serum_creatinine','sex', 'time']]


Y=data['DEATH_EVENT']

# %%
x_new_train,x_new_test,y_new_train,y_new_test=train_test_split(X,Y,test_size=0.20,random_state=43)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_new_train_scaled = scaler.fit_transform(x_new_train)
x_new_test_scaled = scaler.transform(x_new_test)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(x_new_train,y_new_train)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x_new_train.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))
# Out:
#                       Specs         Score
# 5                 platelets  18689.110795
# 8                      time   2998.670054
# 1  creatinine_phosphokinase   2408.916622
# 3         ejection_fraction     55.721264
# 0                       age     23.208486
# 6          serum_creatinine     12.553909
# 4       high_blood_pressure      2.126858
# 7                       sex      0.038256
# 2                  diabetes      0.013526
# c:\Users\Hp\anaconda3\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning:
#
# k=10 is greater than n_features=9. All the features will be returned.

# %%
import plotly.express as px
fig = px.bar(
    featureScores.nlargest(10, 'Score'),  
    x='Specs', 
    y='Score', 
    text='Score', 
    title='Top 10 Features Based on Chi-Squared Scores',
    labels={'Specs': 'Feature', 'Score': 'Chi-Squared Score'},
)
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')
fig.update_layout(
    xaxis_tickangle=45,  
    height=500,
    width=800,
)
fig.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
R2 = LogisticRegression( C=0.2, solver='newton-cholesky')
R2.fit(x_new_train_scaled , y_new_train)
prediction1 = R2.predict(x_new_train_scaled )
prediction2 = R2.predict(x_new_test_scaled )
print(" Train Accuracy :", metrics.accuracy_score(y_new_train, prediction1))
print(" Test Accuracy :", metrics.accuracy_score(y_new_test, prediction2))
print("Precision score:", metrics.precision_score(y_new_test , prediction))
print("Recall score:", metrics.recall_score(y_new_test, prediction))
# Out:
#  Train Accuracy : 0.8451882845188284
#  Test Accuracy : 0.85
# Precision score: 0.8823529411764706
# Recall score: 0.5769230769230769

# %% [markdown]
# ###### Through feature selection and Logistic Regression testing accuracy score was found to be  0.85

# %% [markdown]
# ### Summary:
# #1. Individuals who are non-anemic, non-diabetic, and without high blood pressure have experienced relatively more deaths due to heart failure!! (Potential reason: May be due to unbalanced data of target column 'DEATH_EVENT' [0>1])
#
# #2. <1000 mcg/L Creatinine Phosphokinase, 20%-40% Ejection fraction, 60,000-70,000 kiloplatelets/mL platelets,follow up time of <=50 days (more specifically less than 30 days) ,130-140 mEq/L serum sodium,0-2 mg/dL serum_creatinine and 40-80 years old are more prone to heart failure because it has caused relatively higher death.
#
# #3. Imp Features:Age, ejection_fraction,Platelets,serum_creatinine,creatinine_phosphokinase and time
